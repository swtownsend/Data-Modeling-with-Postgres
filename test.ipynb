# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, 1542845032796, 15, 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (2, 1542845350796, 15, 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, 1542845526796, 15, 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (4, 1542845741796, 15, 'paid', None, None, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(15, 'Lily', 'Koch', 'F', 'paid'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (97, 'Kate', 'Harrell', 'F', 'paid'),
#  (101, 'Jayden', 'Fox', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, Decimal('114.78159')),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, Decimal('218.77506')),
#  ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, Decimal('233.40363')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, Decimal('266.39628')),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, Decimal('267.7024'))]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', Decimal('NaN'), Decimal('NaN')),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', Decimal('35.21962'), Decimal('-80.01955')),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', Decimal('NaN'), Decimal('NaN')),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.time(0, 3, 52, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.time(0, 9, 10, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.time(0, 12, 6, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.time(0, 15, 41, 796000), 0, 22, 47, 11, 2018, 3),
#  (datetime.time(0, 23, 40, 796000), 0, 22, 47, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select  count(songplays.artist_id),artist.name FROM songplays JOIN artist on songplays.artist_id = artist.artist_id GROUP BY artist.name
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# (psycopg2.ProgrammingError) relation "artist" does not exist
# LINE 1: ...gplays.artist_id),artist.name FROM songplays JOIN artist on ...
#                                                              ^
#  [SQL: 'select  count(songplays.artist_id),artist.name FROM songplays JOIN artist on songplays.artist_id = artist.artist_id GROUP BY artist.name']

# %%
# %sql select count(users.user_id),users.level,users.gender FROM users GROUP BY users.level,users.gender
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 4 rows affected.
# [(41, 'free', 'F'), (36, 'free', 'M'), (5, 'paid', 'M'), (14, 'paid', 'F')]

# %%
# %sql select songplays.song_id ,songplays.artist_id from songplays where  songplays.song_id != 'None' or songplays.artist_id != 'None'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4')]

# %%
# %sql SELECT count(songplays.user_id), users.user_id, users.first_name,users.last_name,users.level  FROM songplays join users on songplays.user_id = users.user_id  group by users.user_id, users.first_name,users.last_name,users.level order by users.level desc
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [(9, 20, 'Aiden', 'Ramirez', 'paid'),
#  (689, 49, 'Chloe', 'Cuevas', 'paid'),
#  (346, 29, 'Jacqueline', 'Lynch', 'paid'),
#  (140, 58, 'Emily', 'Benson', 'paid'),
#  (33, 70, 'Jaleah', 'Hayes', 'paid'),
#  (87, 82, 'Avery', 'Martinez', 'paid'),
#  (213, 95, 'Sara', 'Johnson', 'paid'),
#  (192, 30, 'Avery', 'Watkins', 'paid'),
#  (463, 15, 'Lily', 'Koch', 'paid'),
#  (248, 36, 'Matthew', 'Jones', 'paid'),
#  (140, 42, 'Harper', 'Barrett', 'paid'),
#  (397, 44, 'Aleena', 'Kirby', 'paid'),
#  (72, 72, 'Hayden', 'Brock', 'paid'),
#  (169, 25, 'Jayden', 'Graves', 'paid'),
#  (179, 85, 'Kinsley', 'Young', 'paid'),
#  (321, 24, 'Layla', 'Griffin', 'paid'),
#  (641, 97, 'Kate', 'Harrell', 'paid'),
#  (289, 73, 'Jacob', 'Klein', 'paid'),
#  (17, 65, 'Amiya', 'Davidson', 'paid'),
#  (27, 54, 'Kaleb', 'Cook', 'free'),
#  (3, 90, 'Andrea', 'Butler', 'free'),
#  (10, 89, 'Kynnedi', 'Sanchez', 'free'),
# ...
